# %%
import pandas as pd

bfr = pd.read_feather("BarraFactorReturn.txt")
print(bfr.head())
# Out:
#         time      Beta  BooktoPrice  EarningYield    Growth  Leverage  \
# 0 2005-01-05  0.005326     0.001232     -0.002660 -0.001697 -0.000459
# 1 2005-01-06 -0.001601     0.000320     -0.001015  0.000158  0.000036
# 2 2005-01-07  0.000819     0.001264     -0.001177 -0.000771 -0.000941
# 3 2005-01-10  0.002667     0.000175     -0.000807 -0.000343 -0.000286
# 4 2005-01-11 -0.000180     0.001233      0.000288 -0.000615  0.000156
#
#    Liquidity  Momentum  NonlinearSize  ResidualVolatility  ...  电力设备及新能源  \
# 0   0.002822 -0.002522      -0.000053            0.003272  ... -0.001516
# 1  -0.000486 -0.000780      -0.000704           -0.000654  ... -0.001001
# 2  -0.000514 -0.002738      -0.000973            0.001064  ... -0.000914
# 3   0.001051 -0.000532      -0.000243            0.000946  ... -0.003683
# 4  -0.000352 -0.000148      -0.000965            0.000229  ... -0.000407
#
#        国防军工        汽车      商贸零售     消费者服务        家电      纺织服装        医药  \
# ...
